# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

if not os.path.exists("/content/MELD_RAW/MELD.Raw"):
    with zipfile.ZipFile("/content/drive/MyDrive/MELD-RAW.zip", "r") as zip_ref:
        zip_ref.extractall("/content/MELD_RAW")


print("Dataset Ready!")
# Out:
# Dataset Ready!

# %%
import os

for root, dirs, files in os.walk("/content/MELD_RAW"):
    print(root)
# Out:
# /content/MELD_RAW
# /content/MELD_RAW/MELD.Raw
# /content/MELD_RAW/MELD.Raw/dev
# /content/MELD_RAW/MELD.Raw/dev/dev_splits_complete
# /content/MELD_RAW/MELD.Raw/test
# /content/MELD_RAW/MELD.Raw/test/output_repeated_splits_test
# /content/MELD_RAW/MELD.Raw/train
# /content/MELD_RAW/MELD.Raw/train/train_splits

# %%
import pandas as pd

train_df = pd.read_csv("/content/MELD_RAW/MELD.Raw/train/train_sent_emo.csv")
dev_df   = pd.read_csv("/content/MELD_RAW/MELD.Raw/dev_sent_emo.csv")
test_df  = pd.read_csv("/content/MELD_RAW/MELD.Raw/test_sent_emo.csv")

print(train_df.shape)
print(dev_df.shape)
print(test_df.shape)
# Out:
# (9989, 11)
# (1109, 11)
# (2610, 11)

# %%
import numpy as np
import os

base = "/content/drive/MyDrive/DMIC2/embeddings"

dev_text = np.load(os.path.join(base, "dev_text_pca.npy"))
dev_audio = np.load(os.path.join(base, "dev_audio_pca.npy"))
dev_video = np.load(os.path.join(base, "dev_video_pca.npy"))

print(dev_text.shape)
print(dev_audio.shape)
print(dev_video.shape)
# Out:
# (1108, 256)
# (1108, 128)
# (1108, 16)

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cpu

# %%
import pickle
import numpy as np

base = "/content/drive/MyDrive/DMIC2/embeddings"

with open("/content/drive/MyDrive/DMIC2/checkpoints/text_pca.pkl","rb") as f:
    text_pca_model = pickle.load(f)

# %%
test_text_embeddings = np.load(f"{base}/test_text_embeddings.npy")

print(test_text_embeddings.shape)
# Out:
# (2610, 768)

# %%
test_text_pca = text_pca_model.transform(test_text_embeddings)

print(test_text_pca.shape)
# Out:
# (2610, 256)

# %%
np.save(f"{base}/test_text_pca.npy", test_text_pca)

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
base = "/content/drive/MyDrive/DMIC2/embeddings"

train_text = np.load(os.path.join(base, "train_text_pca.npy"))
train_audio = np.load(os.path.join(base, "train_audio_pca.npy"))
train_video = np.load(os.path.join(base, "train_video_pca.npy"))

dev_text = np.load(os.path.join(base, "dev_text_pca.npy"))
dev_audio = np.load(os.path.join(base, "dev_audio_pca.npy"))
dev_video = np.load(os.path.join(base, "dev_video_pca.npy"))

test_text = np.load(os.path.join(base, "test_text_pca.npy"))
test_audio = np.load(os.path.join(base, "test_audio_pca.npy"))
test_video = np.load(os.path.join(base, "test_video_pca.npy"))

print(train_text.shape)
print(train_audio.shape)
print(train_video.shape)

print(test_text.shape)
print(test_audio.shape)
print(test_video.shape)
# Out:
# (9988, 256)
# (9988, 128)
# (9988, 16)
# (2610, 256)
# (2610, 128)
# (2610, 16)

# %%
print("Train")
print(train_text.shape)
print(train_audio.shape)
print(train_video.shape)

print("\nDev")
print(dev_text.shape)
print(dev_audio.shape)
print(dev_video.shape)

print("\nTest")
print(test_text.shape)
print(test_audio.shape)
print(test_video.shape)
# Out:
# Train
# (9988, 256)
# (9988, 128)
# (9988, 16)
#
# Dev
# (1108, 256)
# (1108, 128)
# (1108, 16)
#
# Test
# (2610, 256)
# (2610, 128)
# (2610, 16)

# %%
import pickle

with open("/content/drive/MyDrive/DMIC2/checkpoints/text_pca.pkl", "rb") as f:
    text_pca_model = pickle.load(f)

with open("/content/drive/MyDrive/DMIC2/checkpoints/audio_pca.pkl", "rb") as f:
    audio_pca_model = pickle.load(f)

with open("/content/drive/MyDrive/DMIC2/checkpoints/video_pca.pkl", "rb") as f:
    video_pca_model = pickle.load(f)

print("PCA Models Loaded Successfully!")
# Out:
# PCA Models Loaded Successfully!

# %%
class ModalityMLP(nn.Module):

    def __init__(self, input_dim, hidden_dim=256):

        super().__init__()

        self.network = nn.Sequential(

            nn.Linear(input_dim, hidden_dim),

            nn.LayerNorm(hidden_dim),

            nn.ReLU(),

            nn.Dropout(0.3)

        )

    def forward(self, x):

        return self.network(x)

# %%
class ContextEncoder(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        encoder = nn.TransformerEncoderLayer(

            d_model=hidden_dim,

            nhead=8,

            dim_feedforward=512,

            dropout=0.1,

            batch_first=True

        )

        self.encoder = nn.TransformerEncoder(

            encoder,

            num_layers=2

        )

    def forward(self, x):

        x = x.unsqueeze(1)

        x = self.encoder(x)

        return x.squeeze(1)

# %%
class UnimodalPredictor(nn.Module):

    def __init__(self, hidden_dim=256, num_classes=3):

        super().__init__()

        self.classifier = nn.Sequential(

            nn.Linear(hidden_dim, 128),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(128, num_classes)

        )

    def forward(self, x):

        return self.classifier(x)

# %%
class ModalityImportanceRanking(nn.Module):

    def __init__(self):
        super().__init__()

    def forward(self, text_logits, audio_logits, video_logits):

        text_score = torch.max(
            torch.softmax(text_logits, dim=1),
            dim=1
        )[0]

        audio_score = torch.max(
            torch.softmax(audio_logits, dim=1),
            dim=1
        )[0]

        video_score = torch.max(
            torch.softmax(video_logits, dim=1),
            dim=1
        )[0]

        scores = torch.stack(
            [text_score, audio_score, video_score],
            dim=1
        )

        return scores

# %%
def rank_modalities(scores):

    ranked_indices = torch.argsort(
        scores,
        dim=1,
        descending=True
    )

    return ranked_indices

# %%
class CrossAttentionBlock(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.attention = nn.MultiheadAttention(
            embed_dim=hidden_dim,
            num_heads=8,
            batch_first=True
        )

        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, query, key, value):

        query = query.unsqueeze(1)
        key = key.unsqueeze(1)
        value = value.unsqueeze(1)

        output, _ = self.attention(
            query,
            key,
            value
        )

        output = self.norm(output + query)

        return output.squeeze(1)

# %%
def select_modalities(text_feat, audio_feat, video_feat, ranked_indices):

    modalities = [text_feat, audio_feat, video_feat]

    primary = []
    secondary = []
    tertiary = []

    for i in range(ranked_indices.size(0)):

        idx = ranked_indices[i]

        primary.append(modalities[idx[0]][i])
        secondary.append(modalities[idx[1]][i])
        tertiary.append(modalities[idx[2]][i])

    primary = torch.stack(primary)
    secondary = torch.stack(secondary)
    tertiary = torch.stack(tertiary)

    return primary, secondary, tertiary

# %%
class Gate(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.gate = nn.Sequential(

            nn.Linear(hidden_dim * 2, hidden_dim),

            nn.Sigmoid()

        )

    def forward(self, x1, x2):

        g = self.gate(
            torch.cat([x1, x2], dim=1)
        )

        return g * x1 + (1 - g) * x2

# %%
class CCAFStage1(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.cross = CrossAttentionBlock(hidden_dim)

        self.gate = Gate(hidden_dim)

    def forward(self, primary, secondary):

        attended = self.cross(
            primary,
            secondary,
            secondary
        )

        fused = self.gate(
            primary,
            attended
        )

        return fused

# %%
class CCAFStage1(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.cross = CrossAttentionBlock(hidden_dim)

        self.gate = Gate(hidden_dim)

    def forward(self, primary, secondary):

        attended = self.cross(
            primary,
            secondary,
            secondary
        )

        fused = self.gate(
            primary,
            attended
        )

        return fused

# %%
class InitialFusion(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.P_from_S = PairwiseCrossAttention(hidden_dim)
        self.P_from_T = PairwiseCrossAttention(hidden_dim)

        self.S_from_P = PairwiseCrossAttention(hidden_dim)
        self.S_from_T = PairwiseCrossAttention(hidden_dim)

        self.T_from_P = PairwiseCrossAttention(hidden_dim)
        self.T_from_S = PairwiseCrossAttention(hidden_dim)

    def forward(self, P, S, T):

        P = self.P_from_T(
                self.P_from_S(P, S),
                T
            )

        S = self.S_from_T(
                self.S_from_P(S, P),
                T
            )

        T = self.T_from_S(
                self.T_from_P(T, P),
                S
            )

        return P, S, T

# %%
class CascadedRefinement(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.PS = PairwiseCrossAttention(hidden_dim)
        self.PST = PairwiseCrossAttention(hidden_dim)

    def forward(self, P, S, T):

        # Stage 1: Primary + Secondary
        PS = self.PS(P, S)

        # Stage 2: Refined (P,S) + Tertiary
        PST = self.PST(PS, T)

        return PST

# %%
class FusionClassifier(nn.Module):

    def __init__(self, hidden_dim=256, num_classes=3):

        super().__init__()

        self.classifier = nn.Sequential(

            nn.Linear(hidden_dim, hidden_dim),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(hidden_dim, num_classes)

        )

    def forward(self, fused):

        return self.classifier(fused)

# %%
class ModalityProjection(nn.Module):

    def __init__(
        self,
        text_dim=256,
        audio_dim=128,
        video_dim=16,
        hidden_dim=256
    ):

        super().__init__()

        self.text_proj = nn.Linear(text_dim, hidden_dim)
        self.audio_proj = nn.Linear(audio_dim, hidden_dim)
        self.video_proj = nn.Linear(video_dim, hidden_dim)

    def forward(self, text, audio, video):

        text = self.text_proj(text)
        audio = self.audio_proj(audio)
        video = self.video_proj(video)

        return text, audio, video

# %%
class ModalityImportance(nn.Module):

    def __init__(self, hidden_dim=256):

        super().__init__()

        self.text_score = nn.Sequential(
            nn.Linear(hidden_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )

        self.audio_score = nn.Sequential(
            nn.Linear(hidden_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )

        self.video_score = nn.Sequential(
            nn.Linear(hidden_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )

        self.softmax = nn.Softmax(dim=1)

    def forward(self, text, audio, video):

        text_score = self.text_score(text)

        audio_score = self.audio_score(audio)

        video_score = self.video_score(video)

        scores = torch.cat(
            [
                text_score,
                audio_score,
                video_score
            ],
            dim=1
        )

        weights = self.softmax(scores)

        return weights

# %%
print("ModalityProjection :", "ModalityProjection" in globals())
print("ContextEncoder :", "ContextEncoder" in globals())
print("ModalityImportance :", "ModalityImportance" in globals())
print("InitialFusion :", "InitialFusion" in globals())
print("CascadedRefinement :", "CascadedRefinement" in globals())
print("FusionClassifier :", "FusionClassifier" in globals())
# Out:
# ModalityProjection : True
# ContextEncoder : True
# ModalityImportance : True
# InitialFusion : True
# CascadedRefinement : True
# FusionClassifier : True

# %%
class DMIC2(nn.Module):

    def __init__(
        self,
        text_dim=256,
        audio_dim=128,
        video_dim=16,
        hidden_dim=256,
        num_classes=3
    ):

        super().__init__()

        # Projection
        self.project = ModalityProjection(
            text_dim,
            audio_dim,
            video_dim,
            hidden_dim
        )

        # Context Encoder
        self.context = ContextEncoder(hidden_dim)

        # Modality Importance
        self.importance = ModalityImportance(hidden_dim)

        # Initial Pairwise Fusion
        self.initial_fusion = InitialFusion(hidden_dim)

        # Cascaded Refinement
        self.refinement = CascadedRefinement(hidden_dim)

        # Final Classifier
        self.classifier = FusionClassifier(
            hidden_dim,
            num_classes
        )
        # Unimodal Heads
        self.text_head = UnimodalHead(hidden_dim, num_classes)
        self.audio_head = UnimodalHead(hidden_dim, num_classes)
        self.video_head = UnimodalHead(hidden_dim, num_classes)

    def forward(
        self,
        text,
        audio,
        video
    ):

        # Projection
        text, audio, video = self.project(
            text,
            audio,
            video
        )

        # Context Encoding
        text = self.context(text)
        audio = self.context(audio)
        video = self.context(video)

        # Importance Scores
        weights = self.importance(
            text,
            audio,
            video
        )

        # -----------------------------
# Sample-wise Dynamic Ranking
# -----------------------------

# weights -> (batch_size, 3)

        sorted_idx = torch.argsort(
          weights,
          dim=1,
          descending=True)

        modalities = torch.stack(
            [
                text,
                audio,
                video
            ],
            dim=1
        )
        batch_size = text.size(0)
        P = modalities[
            torch.arange(batch_size),
            sorted_idx[:, 0]
            ]

        S = modalities[
        torch.arange(batch_size),
        sorted_idx[:, 1]
        ]

        T = modalities[
        torch.arange(batch_size),
        sorted_idx[:, 2]
        ]

        # Initial Pairwise Fusion
        P, S, T = self.initial_fusion(
            P,
            S,
            T
        )

        # Cascaded Refinement
        fused = self.refinement(
            P,
            S,
            T
        )
        # Unimodal Predictions
        text_output = self.text_head(text)

        audio_output = self.audio_head(audio)

        video_output = self.video_head(video)

        # Classification
        output = self.classifier(
            fused
        )

        return (
                output,
                text_output,
                audio_output,
                video_output,
                weights
                )

# %%
classes = [
    "ModalityProjection",
    "ContextEncoder",
    "CrossAttentionBlock",
    "Gate",
    "PairwiseCrossAttention",
    "InitialFusion",
    "CascadedRefinement",
    "ModalityImportance",
    "FusionClassifier",
    "DMIC2"
]

for cls in classes:
    print(f"{cls}: {cls in globals()}")
# Out:
# ModalityProjection: True
# ContextEncoder: True
# CrossAttentionBlock: True
# Gate: True
# PairwiseCrossAttention: False
# InitialFusion: True
# CascadedRefinement: True
# ModalityImportance: True
# FusionClassifier: True
# DMIC2: True

# %%
class PairwiseCrossAttention(nn.Module):

    def __init__(self, hidden_dim=256):
        super().__init__()

        self.cross = CrossAttentionBlock(hidden_dim)
        self.gate = Gate(hidden_dim)

    def forward(self, target, source):

        attended = self.cross(
            target,
            source,
            source
        )

        fused = self.gate(
            target,
            attended
        )

        return fused

# %%
train_df = pd.read_csv("/content/MELD_RAW/MELD.Raw/train/train_sent_emo.csv")
dev_df = pd.read_csv("/content/MELD_RAW/MELD.Raw/dev_sent_emo.csv")
test_df = pd.read_csv("/content/MELD_RAW/MELD.Raw/test_sent_emo.csv")

label_encoder = LabelEncoder()
label_encoder.fit(train_df["Sentiment"])

train_labels = torch.LongTensor(
    label_encoder.transform(train_df["Sentiment"])[:9988]
)

dev_labels = torch.LongTensor(
    label_encoder.transform(dev_df["Sentiment"])[:1108]
)

test_labels = torch.LongTensor(
    label_encoder.transform(test_df["Sentiment"])[:2610]
)

print(train_labels.shape)
print(dev_labels.shape)
print(test_labels.shape)
# Out:
# torch.Size([9988])
# torch.Size([1108])
# torch.Size([2610])

# %%
from torch.utils.data import Dataset

class MELDDataset(Dataset):

    def __init__(self, text, audio, video, labels):

        self.text = text
        self.audio = audio
        self.video = video
        self.labels = labels

    def __len__(self):

        return len(self.labels)

    def __getitem__(self, idx):

        return (
            self.text[idx],
            self.audio[idx],
            self.video[idx],
            self.labels[idx]
        )

# %%
train_dataset = MELDDataset(
    train_text,
    train_audio,
    train_video,
    train_labels
)

dev_dataset = MELDDataset(
    dev_text,
    dev_audio,
    dev_video,
    dev_labels
)

test_dataset = MELDDataset(
    test_text,
    test_audio,
    test_video,
    test_labels
)

print(len(train_dataset))
print(len(dev_dataset))
print(len(test_dataset))
# Out:
# 9988
# 1108
# 2610

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

dev_loader = DataLoader(
    dev_dataset,
    batch_size=32,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)

print(len(train_loader))
print(len(dev_loader))
print(len(test_loader))
# Out:
# 313
# 35
# 82

# %%
class UnimodalHead(nn.Module):

    def __init__(self, hidden_dim=256, num_classes=3):
        super().__init__()

        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):

        # Global Average Pooling (Removed, as input is already a feature vector)
        # x = x.mean(dim=1)

        return self.classifier(x)

# %%
print("train_labels" in globals())
# Out:
# True

# %%
print("Train Text :", train_text.shape)
print("Train Audio:", train_audio.shape)
print("Train Video:", train_video.shape)

print("Train Labels:", train_labels.shape)
# Out:
# Train Text : (9988, 256)
# Train Audio: (9988, 128)
# Train Video: (9988, 16)
# Train Labels: torch.Size([9988])

# %%
model = DMIC2()

print(model)
# Out:
# DMIC2(
#   (project): ModalityProjection(
#     (text_proj): Linear(in_features=256, out_features=256, bias=True)
#     (audio_proj): Linear(in_features=128, out_features=256, bias=True)
#     (video_proj): Linear(in_features=16, out_features=256, bias=True)
#   )
#   (context): ContextEncoder(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=512, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=512, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (importance): ModalityImportance(
#     (text_score): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (audio_score): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (video_score): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (softmax): Softmax(dim=1)
#   )
#   (initial_fusion): InitialFusion(
#     (P_from_S): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#     (P_from_T): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#     (S_from_P): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#     (S_from_T): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#     (T_from_P): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#     (T_from_S): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#   )
#   (refinement): CascadedRefinement(
#     (PS): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#     (PST): PairwiseCrossAttention(
#       (cross): CrossAttentionBlock(
#         (attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (gate): Gate(
#         (gate): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Sigmoid()
#         )
#       )
#     )
#   )
#   (classifier): FusionClassifier(
#     (classifier): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=256, out_features=3, bias=True)
#     )
#   )
#   (text_head): UnimodalHead(
#     (classifier): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=128, out_features=3, bias=True)
#     )
#   )
#   (audio_head): UnimodalHead(
#     (classifier): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=128, out_features=3, bias=True)
#     )
#   )
#   (video_head): UnimodalHead(
#     (classifier): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=128, out_features=3, bias=True)
#     )
#   )
# )

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=1e-4
)

# %%
batch = next(iter(train_loader))

text, audio, video, labels = batch

print(text.shape)
print(audio.shape)
print(video.shape)
print(labels.shape)
# Out:
# torch.Size([32, 256])
# torch.Size([32, 128])
# torch.Size([32, 16])
# torch.Size([32])

# %%
model = DMIC2().to(device)

batch = next(iter(train_loader))

text, audio, video, labels = batch

text = text.to(device)
audio = audio.to(device)
video = video.to(device)

outputs, text_out, audio_out, video_out, weights = model(
    text,
    audio,
    video
)

print(outputs.shape)
print(weights.shape)
# Out:
# torch.Size([32, 3])
# torch.Size([32, 3])

# %%
criterion_fused = nn.CrossEntropyLoss()

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = DMIC2().to(device)

# %%
criterion_uni = nn.CrossEntropyLoss()

# %%
fusion_loss = criterion_fused(outputs, labels.to(device))

text_loss = criterion_uni(text_out, labels.to(device))
audio_loss = criterion_uni(audio_out, labels.to(device))
video_loss = criterion_uni(video_out, labels.to(device))

print("Fusion Loss :", fusion_loss.item())
print("Text Loss   :", text_loss.item())
print("Audio Loss  :", audio_loss.item())
print("Video Loss  :", video_loss.item())
# Out:
# Fusion Loss : 1.1423814296722412
# Text Loss   : 1.1014991998672485
# Audio Loss  : 1.1214197874069214
# Video Loss  : 0.9751096963882446

# %%
uni_loss = text_loss + audio_loss + video_loss

print("Unimodal Loss :", uni_loss.item())
# Out:
# Unimodal Loss : 3.198028564453125

# %%
import torch.optim as optim

# Hyperparameters (from the paper)
alpha = 1.0
beta = 0.01
gamma = 0.2

# Optimizer
optimizer = optim.AdamW(
    model.parameters(),
    lr=5e-5,
    weight_decay=1e-4
)

# Learning Rate Scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=2
)

print("Optimizer and Scheduler Created Successfully!")
# Out:
# Optimizer and Scheduler Created Successfully!

# %%
import torch.nn.functional as F

def importance_loss(weights, text_loss, audio_loss, video_loss):
    """
    Compute target modality importance from unimodal losses.
    Lower loss -> Higher importance.
    """

    losses = torch.tensor(
        [
            text_loss.detach(),
            audio_loss.detach(),
            video_loss.detach()
        ],
        device=weights.device
    )

    # Inverse loss (smaller loss = larger importance)
    target = 1.0 / (losses + 1e-8)

    # Normalize
    target = target / target.sum()

    # Repeat for whole batch
    target = target.unsqueeze(0).repeat(weights.size(0), 1)

    # MSE Loss
    loss = F.mse_loss(weights, target)

    return loss

# %%
imp_loss = importance_loss(
    weights,
    text_loss,
    audio_loss,
    video_loss
)

print("Importance Loss :", imp_loss.item())
# Out:
# Importance Loss : 0.013373407535254955

# %%
def balance_loss(weights):
    """
    Encourage balanced use of all modalities.
    """

    target = torch.ones(3, device=weights.device) / 3

    batch_mean = weights.mean(dim=0)

    loss = F.mse_loss(batch_mean, target)

    return loss

# %%
bal_loss = balance_loss(weights)

print("Balance Loss :", bal_loss.item())
# Out:
# Balance Loss : 0.01705205626785755

# %%
total_loss = (
    fusion_loss
    + alpha * imp_loss
    + beta * bal_loss
    + gamma * uni_loss
)
print("Total Loss :", total_loss.item())
# Out:
# Total Loss : 1.7955310344696045

# %%
def train_one_epoch(
    model,
    train_loader,
    optimizer,
    device
):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    for text, audio, video, labels in train_loader:

        text = text.to(device)
        audio = audio.to(device)
        video = video.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        # DMIC2Model now returns only one output
        outputs = model(
            text,
            audio,
            video
        )

        # Use the single criterion for the final output
        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = outputs.max(1)

        correct += predicted.eq(labels).sum().item()

        total += labels.size(0)

    epoch_loss = running_loss / len(train_loader)

    epoch_acc = correct / total

    return epoch_loss, epoch_acc

# %%
print(train_one_epoch)
# Out:
# <function train_one_epoch at 0x7aa807bf3060>

# %%
@torch.no_grad()
def validate(
    model,
    val_loader,
    device
):

    model.eval()

    running_loss = 0
    correct = 0
    total = 0

    for text, audio, video, labels in val_loader:

        text = text.to(device)
        audio = audio.to(device)
        video = video.to(device)
        labels = labels.to(device)

        # DMIC2Model now returns only one output
        outputs = model(
            text,
            audio,
            video
        )

        # Use the single criterion for the final output
        loss = criterion(outputs, labels)

        running_loss += loss.item()

        _, predicted = outputs.max(1)

        correct += predicted.eq(labels).sum().item()

        total += labels.size(0)

    epoch_loss = running_loss / len(val_loader)

    epoch_acc = correct / total

    return epoch_loss, epoch_acc

# %%
print(validate)
# Out:
# <function validate at 0x7aa807b91bc0>

# %%
model.load_state_dict(torch.load("best_dmic2_model.pth", map_location=device))

print("✅ Best Model Loaded Successfully!")

# %%
from sklearn.metrics import accuracy_score, f1_score

@torch.no_grad()
def test(model, test_loader, device):

    model.eval()

    all_preds = []
    all_labels = []

    for text, audio, video, labels in test_loader:

        text = text.to(device)
        audio = audio.to(device)
        video = video.to(device)

        outputs, _, _, _, _ = model(text, audio, video)

        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average="weighted")

    return accuracy, f1, all_labels, all_preds

# %%
accuracy, f1, y_true, y_pred = test(
    model,
    test_loader,
    device
)

print(f"Test Accuracy : {accuracy:.4f}")
print(f"Weighted F1   : {f1:.4f}")

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    digits=4
))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    y_true,
    y_pred
)

print(cm)

# %%
torch.save(
    model.state_dict(),
    "DMIC2_Final_Model.pth"
)

print("✅ Final Model Saved")

# %%
#emotionak prototype memory

import torch
import torch.nn as nn
import torch.nn.functional as F

class EmotionPrototypeMemory(nn.Module):

    def __init__(self, feature_dim=256, num_classes=3):

        super(EmotionPrototypeMemory, self).__init__()

        # Learnable emotion prototypes
        self.prototypes = nn.Parameter(
            torch.randn(num_classes, feature_dim)
        )

        # Temperature parameter
        self.temperature = 0.1

    def forward(self, fused_feature):

        # Normalize
        fused_feature = F.normalize(fused_feature, dim=1)
        prototypes = F.normalize(self.prototypes, dim=1)

        # Cosine similarity
        similarity = torch.matmul(
            fused_feature,
            prototypes.T
        )

        similarity = similarity / self.temperature

        # Attention weights
        weights = F.softmax(similarity, dim=1)

        # Prototype aggregation
        prototype_feature = torch.matmul(
            weights,
            prototypes
        )

        # Feature refinement
        refined_feature = fused_feature + prototype_feature

        return refined_feature

# %%
class DMIC2Model(nn.Module):

    def __init__(self, num_classes=3):

        super().__init__()

        # Projection Layers
        self.text_proj = Projection(256, 256)
        self.audio_proj = Projection(128, 256)
        self.video_proj = Projection(16, 256)

        # Context Transformers
        self.text_tf = ContextTransformer(256)
        self.audio_tf = ContextTransformer(256)
        self.video_tf = ContextTransformer(256)

        # Modality Importance Ranking
        self.mir = ModalityImportance(256)

        # Cross Attention
        self.cross = CrossAttention(256)

        # Gated Fusion
        self.gate = GatedFusion(256)

        # ======================================================
        # NEW : Emotion Prototype Memory (Our Contribution)
        # ======================================================
        self.epm = EmotionPrototypeMemory(
            feature_dim=256,
            num_classes=num_classes
        )

        # Final Classifier
        self.classifier = nn.Sequential(

            nn.Linear(256,128),

            nn.ReLU(),

            nn.Dropout(0.3),

            nn.Linear(128,num_classes)

        )

    def forward(self, text, audio, video):

        # -------------------------
        # Projection
        # -------------------------
        text = self.text_proj(text)
        audio = self.audio_proj(audio)
        video = self.video_proj(video)

        # -------------------------
        # Context Transformer
        # -------------------------
        text = self.text_tf(text)
        audio = self.audio_tf(audio)
        video = self.video_tf(video)

        # -------------------------
        # Modality Importance
        # -------------------------
        weights = self.mir(text, audio, video)

        wt = weights[:,0].unsqueeze(1)
        wa = weights[:,1].unsqueeze(1)
        wv = weights[:,2].unsqueeze(1)

        text = text * wt
        audio = audio * wa
        video = video * wv

        # -------------------------
        # Cascaded Cross Attention
        # -------------------------
        ta = self.cross(text, audio, audio)
        tav = self.cross(ta, video, video)

        # -------------------------
        # Gated Fusion
        # -------------------------
        fused = self.gate(ta, tav)

        # ======================================================
        # Emotion Prototype Memory
        prototype_feature = self.epm(fused)

# Residual Fusion (Our Contribution)
        fused = fused + 0.2 * (prototype_feature - fused)

# Classification
        output = self.classifier(fused)

        return output

# %%
print("Projection :", "Projection" in globals())
print("ContextTransformer :", "ContextTransformer" in globals())
print("CrossAttention :", "CrossAttention" in globals())
print("GatedFusion :", "GatedFusion" in globals())
print("ModalityImportance :", "ModalityImportance" in globals())
# Out:
# Projection : False
# ContextTransformer : False
# CrossAttention : False
# GatedFusion : False
# ModalityImportance : True

# %%
class Projection(nn.Module):

    def __init__(self, input_dim, hidden_dim=256):

        super().__init__()

        self.layer = nn.Sequential(

            nn.Linear(input_dim, hidden_dim),

            nn.ReLU(),

            nn.Dropout(0.3)

        )

    def forward(self, x):

        return self.layer(x)

# %%
class ContextTransformer(nn.Module):

    def __init__(self, dim=256):

        super().__init__()

        encoder = nn.TransformerEncoderLayer(

            d_model=dim,

            nhead=8,

            batch_first=True

        )

        self.transformer = nn.TransformerEncoder(

            encoder,

            num_layers=2
        )

    def forward(self, x):

        x = x.unsqueeze(1)

        x = self.transformer(x)

        return x.squeeze(1)

# %%
class CrossAttention(nn.Module):

    def __init__(self, dim=256):

        super().__init__()

        self.attention = nn.MultiheadAttention(
            embed_dim=dim,
            num_heads=8,
            batch_first=True
        )

    def forward(self, query, key, value):

        query = query.unsqueeze(1)
        key = key.unsqueeze(1)
        value = value.unsqueeze(1)

        output, _ = self.attention(
            query,
            key,
            value
        )

        return output.squeeze(1)

# %%
class GatedFusion(nn.Module):

    def __init__(self, dim=256):

        super().__init__()

        self.gate = nn.Sequential(

            nn.Linear(dim * 2, dim),

            nn.Sigmoid()

        )

    def forward(self, x1, x2):

        gate = self.gate(
            torch.cat([x1, x2], dim=1)
        )

        fused = gate * x1 + (1 - gate) * x2

        return fused

# %%
model = DMIC2Model().to(device)

print(model)
# Out:
# DMIC2Model(
#   (text_proj): Projection(
#     (layer): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (audio_proj): Projection(
#     (layer): Sequential(
#       (0): Linear(in_features=128, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (video_proj): Projection(
#     (layer): Sequential(
#       (0): Linear(in_features=16, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (text_tf): ContextTransformer(
#     (transformer): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (audio_tf): ContextTransformer(
#     (transformer): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (video_tf): ContextTransformer(
#     (transformer): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (mir): ModalityImportance(
#     (text_score): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (audio_score): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (video_score): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (softmax): Softmax(dim=1)
#   )
#   (cross): CrossAttention(
#     (attention): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (gate): GatedFusion(
#     (gate): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (epm): EmotionPrototypeMemory()
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
text, audio, video, labels = next(iter(train_loader))

text = text.float().to(device)
audio = audio.float().to(device)
video = video.float().to(device)

outputs = model(text, audio, video)

print(outputs.shape)
# Out:
# torch.Size([32, 3])

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-4
)

# %%
print (train_one_epoch)
# Out:
# <function train_one_epoch at 0x7aa807bf3060>

# %%
import inspect

print(inspect.signature(train_one_epoch))
# Out:
# (model, train_loader, optimizer, device)

# %%
outputs = model(
    text,
    audio,
    video
)

# %%
train_one_epoch(model, train_loader, optimizer, device)
# Out:
# (1.0591429892820292, 0.4662595114136964)

# %%
# ===========================================
# FINAL TRAINING LOOP
# ===========================================

num_epochs = 20

best_acc = 0.0

for epoch in range(num_epochs):

    train_loss, train_acc = train_one_epoch(
        model,
        train_loader,
        optimizer,
        device
    )

    val_loss, val_acc = validate(
        model,
        dev_loader,
        device
    )

    scheduler.step(val_loss)

    print("=" * 60)
    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"Train Loss : {train_loss:.4f}")
    print(f"Train Acc  : {train_acc:.4f}")
    print(f"Val Loss   : {val_loss:.4f}")
    print(f"Val Acc    : {val_acc:.4f}")

    if val_acc > best_acc:

        best_acc = val_acc

        torch.save(
            model.state_dict(),
            "best_dmic2_model.pth"
        )

        print("✅ Best Model Saved!")

print("\n🎉 Training Finished!")
print(f"Best Validation Accuracy : {best_acc:.4f}")
# Out:
# ============================================================
# Epoch 1/20
# Train Loss : 1.0467
# Train Acc  : 0.4711
# Val Loss   : 1.0362
# Val Acc    : 0.4242
# ✅ Best Model Saved!
# ============================================================
# Epoch 2/20
# Train Loss : 1.0393
# Train Acc  : 0.4827
# Val Loss   : 1.0316
# Val Acc    : 0.5442
# ✅ Best Model Saved!
# ============================================================
# Epoch 3/20
# Train Loss : 1.0363
# Train Acc  : 0.4909
# Val Loss   : 1.0191
# Val Acc    : 0.5587
# ✅ Best Model Saved!
# ============================================================
# Epoch 4/20
# Train Loss : 1.0347
# Train Acc  : 0.4821
# Val Loss   : 1.0107
# Val Acc    : 0.5758
# ✅ Best Model Saved!
# ============================================================
# Epoch 5/20
# Train Loss : 1.0311
# Train Acc  : 0.4937
# Val Loss   : 1.0096
# Val Acc    : 0.5686
# ============================================================
# Epoch 6/20
# Train Loss : 1.0266
# Train Acc  : 0.5017
# Val Loss   : 1.0018
# Val Acc    : 0.5641
# ============================================================
# Epoch 7/20
# Train Loss : 1.0215
# Train Acc  : 0.5079
# Val Loss   : 1.0009
# Val Acc    : 0.5560
# ============================================================
# Epoch 8/20
# Train Loss : 1.0200
# Train Acc  : 0.5085
# Val Loss   : 1.0037
# Val Acc    : 0.5569
# ============================================================
# Epoch 9/20
# Train Loss : 1.0179
# Train Acc  : 0.5121
# Val Loss   : 1.0150
# Val Acc    : 0.5316
# ============================================================
# Epoch 10/20
# Train Loss : 1.0103
# Train Acc  : 0.5219
# Val Loss   : 1.0052
# Val Acc    : 0.5623
# ============================================================
# Epoch 11/20
# Train Loss : 1.0109
# Train Acc  : 0.5192
# Val Loss   : 1.0080
# Val Acc    : 0.5397
# ============================================================
# Epoch 12/20
# Train Loss : 1.0065
# Train Acc  : 0.5285
# Val Loss   : 1.0067
# Val Acc    : 0.5514
# ============================================================
# Epoch 13/20
# Train Loss : 0.9997
# Train Acc  : 0.5272
# Val Loss   : 1.0020
# Val Acc    : 0.5433
# ============================================================
# Epoch 14/20
# Train Loss : 0.9972
# Train Acc  : 0.5357
# Val Loss   : 1.0005
# Val Acc    : 0.5460
# ============================================================
# Epoch 15/20
# Train Loss : 0.9943
# Train Acc  : 0.5358
# Val Loss   : 1.0073
# Val Acc    : 0.5406
# ============================================================
# Epoch 16/20
# Train Loss : 0.9882
# Train Acc  : 0.5451
# Val Loss   : 1.0044
# Val Acc    : 0.5487
# ============================================================
# Epoch 17/20
# Train Loss : 0.9838
# Train Acc  : 0.5427
# Val Loss   : 1.0132
# Val Acc    : 0.5388
# ============================================================
# Epoch 18/20
# Train Loss : 0.9800
# Train Acc  : 0.5487
# Val Loss   : 1.0143
# Val Acc    : 0.5397
# ============================================================
# Epoch 19/20
# Train Loss : 0.9729
# Train Acc  : 0.5538
# Val Loss   : 1.0222
# Val Acc    : 0.5379
# ============================================================
# Epoch 20/20
# Train Loss : 0.9695
# Train Acc  : 0.5559
# Val Loss   : 1.0612
# Val Acc    : 0.5153
#
# 🎉 Training Finished!
# Best Validation Accuracy : 0.5758

# %%
from sklearn.metrics import accuracy_score

model.eval()

y_true = []
y_pred = []

with torch.no_grad():

    for text, audio, video, labels in test_loader:

        text = text.to(device).float()
        audio = audio.to(device).float()
        video = video.to(device).float()
        labels = labels.to(device)

        outputs = model(text, audio, video)

        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

print("Test Accuracy:", accuracy_score(y_true, y_pred))
# Out:
# Test Accuracy: 0.5459770114942529

# %%
from sklearn.metrics import accuracy_score, f1_score

@torch.no_grad()
def test(model, test_loader, device):

    model.eval()

    all_preds = []
    all_labels = []

    for text, audio, video, labels in test_loader:

        text = text.to(device)
        audio = audio.to(device)
        video = video.to(device)

        outputs, _, _, _, _ = model(text, audio, video)

        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average="weighted")

    return accuracy, f1, all_labels, all_preds

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    digits=4
))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5829    0.4010    0.4751       833
#            1     0.5356    0.8686    0.6626      1256
#            2     0.0000    0.0000    0.0000       521
#
#     accuracy                         0.5460      2610
#    macro avg     0.3728    0.4232    0.3792      2610
# weighted avg     0.4438    0.5460    0.4705      2610
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    y_true,
    y_pred
)

print(cm)
# Out:
# [[ 334  499    0]
#  [ 165 1091    0]
#  [  74  447    0]]

# %%
import numpy as np

unique, counts = np.unique(y_pred, return_counts=True)

for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")
# Out:
# Class 0: 573
# Class 1: 2037

# %%
print(torch.unique(train_labels, return_counts=True))
# Out:
# (tensor([0, 1, 2]), tensor([2945, 4710, 2333]))

# %%
print(torch.unique(dev_labels, return_counts=True))
# Out:
# (tensor([0, 1, 2]), tensor([405, 470, 233]))

# %%
print(torch.unique(test_labels, return_counts=True))
# Out:
# (tensor([0, 1, 2]), tensor([ 833, 1256,  521]))
